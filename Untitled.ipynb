# %%
# Зчитуємо дані із збереженого нами файлу
import json
data_set = json.load(open("dataset.json"))

# %%
# data_set[0]

# %%
parents = set([x["category"]["parent"] for x in data_set])
# Відбираємо тільки батьківські категорії, та ініціалізовуємо список об'єктів моделі Category
parent_categories = [Category(**dict(name=x)) for x in parents]
# Виконуємо множинний INSERT в нашу таблицю за допомогою методу bulk_create
Category.objects.bulk_create(parent_categories)
# Out:
# [<Category: Category object (2)>,
#  <Category: Category object (3)>,
#  <Category: Category object (4)>]

# %%
# Отримужмо список дочірніх категорій, врахувавши унікальність імені категорій
child_categories = list({v['name']: v for v in [x["category"] for x in data_set]}.values())

# Словник для перетворення імен батьківських категорій в їх раніше створені ID в базі даних
# Має вигляд {"Все ноутбуки": 1, "Все планшет*": 2}
parent_ids = dict(Category.objects.filter(parent__isnull=True).values_list("name", "id"))

# Замінюємо назви на parentID
for child in child_categories:
    child["parent_id"] = parent_ids.get(child.pop("parent", None))

# Виконуємо множинну вставку
Category.objects.bulk_create([Category(**category) for category in child_categories])
# Out:
# [<Category: Category object (14)>,
#  <Category: Category object (15)>,
#  <Category: Category object (16)>,
#  <Category: Category object (17)>,
#  <Category: Category object (18)>,
#  <Category: Category object (19)>,
#  <Category: Category object (20)>,
#  <Category: Category object (21)>,
#  <Category: Category object (22)>]

# %%
# Перейдемо до створення валют в нашій СУБД
# Ініціалізуємо об'єкт валюти Гривні
uan = Currency(name="Гривня", code="UAN")
uan.save()  # Зберігаємо її

# Також за допомогою методу create можна створювати записи
rub = Currency.objects.create(name="Рубль", code="RUB")
rub.delete()  # Видаляємо щойно створений об'єкт

# Створюємо ще один
Currency.objects.create(name="Долар", code="USD")
# Out:
# <Currency: Currency object (3)>

# %%
# Створюємо бренди
brands = [{"name": y} for y in set((x["brand"] for x in data_set)) if y]
Brand.objects.bulk_create([Brand(**x) for x in brands])
# Out:
# [<Brand: Brand object (5)>,
#  <Brand: Brand object (6)>,
#  <Brand: Brand object (7)>,
#  <Brand: Brand object (8)>,
#  <Brand: Brand object (9)>]

# %%
from django.core.files import File
import copy, tempfile
from urllib.request import urlopen

products = copy.deepcopy(list({v['name']: v for v in data_set}.values()))

category_ids = dict(Category.objects.filter(parent__isnull=False).values_list("name", "id"))
brand_ids = dict(Brand.objects.all().values_list("name", "id"))

for x in products:
    x.pop("prices", None)
    x["category_id"] = category_ids.get(x.pop("category")["name"])
    x["brand_id"] = brand_ids.get(x.pop("brand"))
    x["detail"] = x.pop("details")
    
    url = x.pop("photo")

    product = Product.objects.create(**x)

    img_temp = tempfile.NamedTemporaryFile(delete=False)
    img_temp.write(urlopen(url).read())
    img_temp.flush()
    photo = File(img_temp)
    product.photo.save(url.split('/')[-1], photo)
    product.save()

# %%
uan_id = Currency.objects.get(code="UAN")
usd_id = Currency.objects.get(code="USD")
product_ids = dict(Product.objects.all().values_list("name", "id"))

# %%
data_set[0]
# Out:
# {'reviews': 6,
#  'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#  'name': 'Ноутбук Acer Aspire 3 A315-21 (NX.GNVEU.014) Black Суперцена!!!',
#  'prices': {'without_discount_grn': 6999,
#   'with_discount_grn': 6199,
#   'with_discount_usd': 233.92,
#   'without_discount_usd': 264.11},
#  'photo': 'https://i2.rozetka.ua/goods/4085311/copy_aser_aspire_3_a315_21g_nx_gq4eu_002_5ad06c83e87c4_images_4085311296.jpg',
#  'brand': 'Acer',
#  'sale': True,
#  'details': 'https://rozetka.com.ua/aser_aspire_3_a315_21_nx_gnveu_014/p38506736/'}

# %%
product_prices = []

products = copy.deepcopy(list({v['name']: v for v in data_set}.values()))

for product in products:
    if not product_ids.get(product["name"]):
        continue
    if product.get("prices", {}).get("without_discount_grn"):
        product_prices.append(ProductPrice(product_id=product_ids[product["name"]],
                                          currency_id=uan_id.id, 
                                          original=product["prices"].get("without_discount_grn"),
                                          discount=product["prices"].get("with_discount_grn", 0),
                                          ))
    if product.get("prices", {}).get("without_discount_usd"):
        product_prices.append(ProductPrice(product_id=product_ids[product["name"]],
                                      currency_id=usd_id.id, 
                                      original=product["prices"].get("without_discount_usd"),
                                      discount=product["prices"].get("with_discount_usd", 0),
                                      ))

# %%
# ProductPrice.objects.bulk_create(product_prices)

# %%
products
# Out:
# [{'reviews': 6,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Aspire 3 A315-21 (NX.GNVEU.014) Black Суперцена!!!',
#   'prices': {'without_discount_grn': 6999,
#    'with_discount_grn': 6199,
#    'with_discount_usd': 233.92,
#    'without_discount_usd': 264.11},
#   'photo': 'https://i2.rozetka.ua/goods/4085311/copy_aser_aspire_3_a315_21g_nx_gq4eu_002_5ad06c83e87c4_images_4085311296.jpg',
#   'brand': 'Acer',
#   'sale': True,
#   'details': 'https://rozetka.com.ua/aser_aspire_3_a315_21_nx_gnveu_014/p38506736/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Extensa EX2519-C313 (NX.EFAEU.054) Black',
#   'prices': {'without_discount_grn': 6999,
#    'with_discount_grn': 6399,
#    'with_discount_usd': 241.47,
#    'without_discount_usd': 264.11},
#   'photo': 'https://i1.rozetka.ua/goods/2404491/copy_acer_nx_efaeu_042_5a27beeadb90e_images_2404491681.jpg',
#   'brand': 'Acer',
#   'sale': True,
#   'details': 'https://rozetka.com.ua/acer_nx_efaeu_054/p27775593/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Aspire 5 A515-41G (NH.GPYEU.001) Obsidian Black Суперцена!!!',
#   'prices': {'without_discount_grn': 18999,
#    'with_discount_grn': 15199,
#    'with_discount_usd': 573.55,
#    'without_discount_usd': 716.94},
#   'photo': 'https://i2.rozetka.ua/goods/3463203/copy_acer_nh_gpyeu_002_5aa2ba245e5ba_images_3463203127.jpg',
#   'brand': 'Acer',
#   'sale': True,
#   'details': 'https://rozetka.com.ua/acer_nh_gpyeu_001/p34723431/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Aspire 5 A515-41G (NH.GPYEU.002) Obsidian Black Суперцена!!!',
#   'prices': {'without_discount_grn': 19999,
#    'with_discount_grn': 16699,
#    'with_discount_usd': 630.15,
#    'without_discount_usd': 754.68},
#   'photo': 'https://i2.rozetka.ua/goods/3463057/copy_acer_nh_gpyeu_003_5aa2b75be7320_images_3463057431.jpg',
#   'brand': 'Acer',
#   'sale': True,
#   'details': 'https://rozetka.com.ua/acer_nh_gpyeu_002/p34723351/'},
#  {'reviews': 3,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Aspire 5 A515-41G (NH.GPYEU.003) Obsidian Black Суперцена!!!',
#   'prices': {'without_discount_grn': 21999,
#    'with_discount_grn': 18299,
#    'with_discount_usd': 690.53,
#    'without_discount_usd': 830.15},
#   'photo': 'https://i1.rozetka.ua/goods/3462608/copy_acer_nx_gt0eu_008_5aa2af5a181f6_images_3462608975.jpg',
#   'brand': 'Acer',
#   'sale': True,
#   'details': 'https://rozetka.com.ua/acer_nh_gpyeu_003/p34721751/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Acer', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Acer Nitro 5 AN515-51 (NH.Q2REU.020) Shale Black',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 24999,
#    'with_discount_usd': 943.36,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/

#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639897/35441055_images_3639897491.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441055/p35441055/'},
#  {'reviews': 1,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1706 MacBook Pro TB Retina 13" (MPXW2) Space Gray',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 50899,
#    'with_discount_usd': 1920.72,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3524702/copy_apple_mpxw2ua_a_5aa79d1dc38de_images_3524702703.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/apple_mpxw2/p34888663/'},
#  {'reviews': 1,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Rose Gold (MNYM2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 33999,
#    'with_discount_usd': 1282.98,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639936/35441076_images_3639936523.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441076/p35441076/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Gold (MNYL2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 40999,
#    'with_discount_usd': 1547.13,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639949/35441538_images_3639949662.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441538/p35441538/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1706 MacBook Pro TB Retina 13" (MPXY2) Silver',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 50999,
#    'with_discount_usd': 1924.49,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639923/35440712_images_3639923251.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35440712/p35440712/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1706 MacBook Pro TB Retina 13" (MPXW2) Space Gray + Apple USB-C - VGA Multiport (MJ1L2ZM/A) в подарок!',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 50999,
#    'with_discount_usd': 1924.49,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639929/35440887_images_3639929103.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35440887/p35440887/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Space Gray (MNYG2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 41599,
#    'with_discount_usd': 1569.77,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639932/35440985_images_3639932988.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35440985/p35440985/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Gold (MNYK2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 34499,
#    'with_discount_usd': 1301.85,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639896/35441027_images_3639896679.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441027/p35441027/'},
#  {'reviews': 2,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1398 MacBook Pro Retina 15" (MJLQ2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 54999,
#    'with_discount_usd': 2075.43,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639900/35441202_images_3639900949.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441202/p35441202/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Space Gray (MNYF2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 34550,
#    'with_discount_usd': 1303.77,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639902/35441216_images_3639902181.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441216/p35441216/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Silver (MNYJ2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 41550,
#    'with_discount_usd': 1567.92,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639903/35441237_images_3639903875.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441237/p35441237/'},
#  {'reviews': 1,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1708 MacBook Pro Retina 13" (MPXU2) Silver',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 39499,
#    'with_discount_usd': 1490.53,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639941/35441321_images_3639941794.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441321/p35441321/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1708 MacBook Pro Retina 13" (MLL42) Space Gray',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 36499,
#    'with_discount_usd': 1377.32,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639914/35441587_images_3639914312.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441587/p35441587/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1706 MacBook Pro TB Retina 13" (MPXV2) Space Gray',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 45850,
#    'with_discount_usd': 1730.19,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639917/35441671_images_3639917686.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441671/p35441671/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1707 MacBook Pro TB Retina 15" (MPTR2) Space Gray',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 59699,
#    'with_discount_usd': 2252.79,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3639956/35441741_images_3639956011.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441741/p35441741/'},
#  {'reviews': 2,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple A1707 MacBook Pro TB Retina 15" (MPTT2) Space Gray',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 68999,
#    'with_discount_usd': 2603.74,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/3639918/35441748_images_3639918834.jpg',
#   'brand': 'Apple',
#   'sale': False,
#   'details': 'https://rozetka.com.ua/35441748/p35441748/'},
#  {'reviews': 0,
#   'category': {'name': 'Ноутбуки Apple', 'parent': 'Все ноутбуки'},
#   'name': 'Ноутбук Apple MacBook A1534 12" Silver (MNYH2)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 34685,
# ...
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 24" LG 24MP68VQ-P + 0,01% кредит на 5 мес',
#   'prices': {'without_discount_grn': 5699,
#    'with_discount_grn': 5299,
#    'with_discount_usd': 199.96,
#    'without_discount_usd': 215.06},
#   'photo': 'https://i1.rozetka.ua/goods/2119745/lg_24mp68vq_p_images_2119745019.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_24mp68vq_p/p19343058/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 27" Samsung Curved C27F396F (LC27F396FHIXCI)',
#   'prices': {'without_discount_grn': 7099,
#    'with_discount_grn': 6649,
#    'with_discount_usd': 250.91,
#    'without_discount_usd': 267.89},
#   'photo': 'https://i1.rozetka.ua/goods/2139822/samsung_c27f396f_images_2139822980.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_c27f396f/p10592292/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" LG 27MP68VQ-P + 0,01% кредит на 5 мес',
#   'prices': {'without_discount_grn': 7299,
#    'with_discount_grn': 6699,
#    'with_discount_usd': 252.79,
#    'without_discount_usd': 275.43},
#   'photo': 'https://i1.rozetka.ua/goods/1642867/lg_27mp68vq_p_images_1642867790.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_27mp68vq_p/p9770184/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 23.5" Samsung Curved C24F396F (LC24F396FHIXCI)',
#   'prices': {'without_discount_grn': 4999,
#    'with_discount_grn': 4749,
#    'with_discount_usd': 179.21,
#    'without_discount_usd': 188.64},
#   'photo': 'https://i2.rozetka.ua/goods/1687190/samsung_c24f396f_images_1687190859.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_c24f396f/p10592250/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" Dell P2417H (210-AJEX)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 6369,
#    'with_discount_usd': 240.34,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/1655686/copy_dell_210_ajeg_577a56fbd156f_images_1655686785.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/dell_210_ajex/p9940081/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 24" Samsung S24D300HS + сертификат на 100грн в подарок!',
#   'prices': {'without_discount_grn': 4099,
#    'with_discount_grn': 3999,
#    'with_discount_usd': 150.91,
#    'without_discount_usd': 154.68},
#   'photo': 'https://i1.rozetka.ua/goods/120527/samsung_ls24d300hs_images_120527955.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_ls24d300hs/p1173155/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" Dell UltraSharp U2717D (210-AICW) + 0.01% кредит на 10 мес',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 17499,
#    'with_discount_usd': 660.34,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/1641050/copy_dell_210_ahjk_575eadf75a2ff_images_1641050359.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/dell_210_aicw/p9730039/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23" Asus VZ239HE + Мышь Asus Cerberus USB в подарок!',
#   'prices': {'without_discount_grn': 5069,
#    'with_discount_grn': 4879,
#    'with_discount_usd': 184.11,
#    'without_discount_usd': 191.28},
#   'photo': 'https://i1.rozetka.ua/goods/2187721/copy_asus_vz229h_59ae7ffaea22f_images_2187721544.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/asus_vz239he/p22223006/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 24" Dell SE2416H Silver-Black',
#   'prices': {'without_discount_grn': 4529,
#    'with_discount_grn': 4369,
#    'with_discount_usd': 164.87,
#    'without_discount_usd': 170.91},
#   'photo': 'https://i1.rozetka.ua/goods/1322410/dell_se2416h_images_1322410190.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/dell_se2416h/p5218112/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.5" Samsung S24F350F (LS24F350FHIXCI)',
#   'prices': {'without_discount_grn': 4399,
#    'with_discount_grn': 4099,
#    'with_discount_usd': 154.68,
#    'without_discount_usd': 166},
#   'photo': 'https://i1.rozetka.ua/goods/1577280/copy_samsung_s24b370h_572b1955a7a7d_images_1577280531.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_s24f350f/p8901719/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" Philips E-Line 276E7QDAB',
#   'prices': {'without_discount_grn': 6299,
#    'with_discount_grn': 5999,
#    'with_discount_usd': 226.38,
#    'without_discount_usd': 237.7},
#   'photo': 'https://i1.rozetka.ua/goods/1864642/philips_276e7qdab_00_images_1864642538.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/philips_276e7qdab_00/p14502572/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" LG 24MP58VQ-P + 0,01% кредит на 5 мес',
#   'prices': {'without_discount_grn': 4999,
#    'with_discount_grn': 4499,
#    'with_discount_usd': 169.77,
#    'without_discount_usd': 188.64},
#   'photo': 'https://i2.rozetka.ua/goods/1497891/lg_24mp58vq_p_images_1497891636.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_24mp58vq_p/p7909821/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23" LG 23MP68VQ-P + 0,01% кредит на 5 мес',
#   'prices': {'without_discount_grn': 4999,
#    'with_discount_grn': 4699,
#    'with_discount_usd': 177.32,
#    'without_discount_usd': 188.64},
#   'photo': 'https://i2.rozetka.ua/goods/1623778/copy_lg_22mp68vq_5747f5e59bdef_images_1623778223.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_23mp68vq/p9369105/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.6" Samsung S24E390H (LS24E390HLO/CI) + сертификат на 100грн в подарок!',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 4899,
#    'with_discount_usd': 184.87,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/1058663/samsung_ls24e390hlo_ci_images_1058663414.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_ls24e390hlo_ci/p4191961/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" LG 24MP88HV-S + 0,01% кредит на 10 мес или Мышь Logitech M185 Wireless в подарок!',
#   'prices': {'without_discount_grn': 6699,
#    'with_discount_grn': 6399,
#    'with_discount_usd': 241.47,
#    'without_discount_usd': 252.79},
#   'photo': 'https://i2.rozetka.ua/goods/1539174/lg_24mp88hv_s_images_1539174974.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_24mp88hv_s/p8411817/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" LG 24MP58D-P + 0.01% кредит на 5 мес или USB-накопитель Kingston в подарок!',
#   'prices': {'without_discount_grn': 4669,
#    'with_discount_grn': 4199,
#    'with_discount_usd': 158.45,
#    'without_discount_usd': 176.19},
#   'photo': 'https://i1.rozetka.ua/goods/1498385/copy_lg_22mp58d_p_56f556b41f91a_images_1498385332.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_24mp58d_p/p7910423/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 25" LG 25UM58-P + 0,01% кредит на 5 мес или USB-накопитель Kingston в подарок!',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 5699,
#    'with_discount_usd': 215.06,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/1498436/lg_25um58_p_images_1498436061.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_25um58_p_bl/p7911949/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 26.9" Samsung Curved C27HG70Q (LC27HG70QQIXCI) + оплата частями',
#   'prices': {'without_discount_grn': 17999,
#    'with_discount_grn': 17099,
#    'with_discount_usd': 645.25,
#    'without_discount_usd': 679.21},
#   'photo': 'https://i2.rozetka.ua/goods/2253573/samsung_lc27hg70qqixci_images_2253573385.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_lc27hg70qqixci1/p24138387/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 31.5" LG 32UD59-B + 0,01% кредит на 10 мес или Клавиатура проводная Roccat Isku FX USB в подарок!',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 18899,
#    'with_discount_usd': 713.17,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/2349851/copy_lg_27ud58_b_5a0ed0fde783a_images_2349851601.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_32ud59/p26474137/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" Dell S2418HN (210-ALTR)',
#   'prices': {'without_discount_grn': 6599,
#    'with_discount_grn': 5899,
#    'with_discount_usd': 222.6,
#    'without_discount_usd': 249.02},
#   'photo': 'https://i2.rozetka.ua/goods/1946808/dell_s2418hn_images_1946808614.jpg',
#   'brand': None,
#   'sale': True,
#   'details': 'https://hard.rozetka.com.ua/dell_s2418hn/p16105274/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 31.5" Philips 323E7QDAB/00',
#   'prices': {'without_discount_grn': 8229,
#    'with_discount_grn': 7275,
#    'with_discount_usd': 274.53,
#    'without_discount_usd': 310.53},
#   'photo': 'https://i1.rozetka.ua/goods/1981275/philips_323e7qdab_00_images_1981275998.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/philips_323e7qdab_00/p16855658/'},
#  {'reviews': 5,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.8" LG 24MK430H-B',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 4099,
#    'with_discount_usd': 154.68,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3622969/lg_24mk430h_b_images_3622969359.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_24mk430h_b/p35376871/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 31.5" Samsung Curved C32HG70 (LC32HG70QQIXCI) + оплата частями',
#   'prices': {'without_discount_grn': 19999,
#    'with_discount_grn': 18999,
#    'with_discount_usd': 716.94,
#    'without_discount_usd': 754.68},
#   'photo': 'https://i1.rozetka.ua/goods/2458465/copy_samsung_lc27hg70qqixci1_5a547befb9175_images_2458465679.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_lc32hg70qqixci/p29647687/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 27" Samsung Curved C27FG73F (LC27FG73FQIXCI) + оплата частями',
#   'prices': {'without_discount_grn': 12999,
#    'with_discount_grn': 12292,
#    'with_discount_usd': 463.85,
#    'without_discount_usd': 490.53},
#   'photo': 'https://i1.rozetka.ua/goods/2117603/samsung_lc27fg73fqixci_images_2117603586.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_lc27fg73fqixci/p20304655/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Mонитор 34" Samsung Curved C34H890WJI (LC34H890WJIXCI) + 0,01% кредит на 10 мес',
#   'prices': {'without_discount_grn': 25999,
#    'with_discount_grn': 22099,
#    'with_discount_usd': 833.92,
#    'without_discount_usd': 981.09},
#   'photo': 'https://i2.rozetka.ua/goods/2159122/samsung_lc34h890wjixci_images_2159122386.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_lc34h890wjixci/p21504519/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 24" BenQ Zowie XL2411P (9H.LGPLB.QBE)',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 9733,
#    'with_discount_usd': 367.28,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/2412170/copy_benq_9h_lellb_rbe_5a2bd1549fabf_images_2412170681.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/benq_xl2411p/p28060473/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 24" Asus ROG Swift PG248Q + смартфон Asus ZenFone Go в подарок!',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 16799,
#    'with_discount_usd': 633.92,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/1740197/copy_asus_rog_swift_pg278q_57e144b4e0c27_images_1740197267.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/asus_rog_swift_pg248q/p11661752/'},
#  {'reviews': 1,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" Samsung S27H650F (LS27H650FDIXCI) Black',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 7651,
#    'with_discount_usd': 288.72,
#    'without_discount_usd': 0},
#   'photo': 'https://i2.rozetka.ua/goods/3669816/copy_samsung_ls24h650fdixci_5ab354ff06cb0_images_3669816640.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/samsung_s27h650fdixci/p35562842/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" Dell SE2717H Silver-Black',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 6749,
#    'with_discount_usd': 254.68,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/1783679/dell_se2717h_images_1783679900.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/dell_se2717h/p12469494/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 27" Philips 273V7QDSB/00',
#   'prices': {'without_discount_grn': 0,
#    'with_discount_grn': 5699,
#    'with_discount_usd': 215.06,
#    'without_discount_usd': 0},
#   'photo': 'https://i1.rozetka.ua/goods/2107607/philips_273v7qdsb_00_images_2107607488.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/philips_273v7qdsb_00/p19758452/'},
#  {'reviews': 2,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 23.6" ViewSonic VX2457-MHD Black (VS16263) + Проводной геймпад SPEEDLINK в подарок!',
#   'prices': {'without_discount_grn': 6300,
#    'with_discount_grn': 5224,
#    'with_discount_usd': 197.13,
#    'without_discount_usd': 237.74},
#   'photo': 'https://i1.rozetka.ua/goods/1481031/copy_viewsonic_vs16261_56e7f69ce5d31_images_1481031989.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/viewsonic_vs16263/p7666186/'},
#  {'reviews': 0,
#   'category': {'name': 'Мониторы 23" + ', 'parent': 'Все мониторы'},
#   'name': 'Монитор 34" LG 34UC89G-B + 0,01% кредит на 10 мес или Клавиатура проводная Roccat Isku FX USB в подарок!',
#   'prices': {'without_discount_grn': 29999,
#    'with_discount_grn': 27999,
#    'with_discount_usd': 1056.57,
#    'without_discount_usd': 1132.04},
#   'photo': 'https://i1.rozetka.ua/goods/2256267/lg_34uc89g_b_images_2256267552.jpg',
#   'brand': None,
#   'sale': False,
#   'details': 'https://hard.rozetka.com.ua/lg_34uc89g_b/p24204621/'}]
